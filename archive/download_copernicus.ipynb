# %%
import cdsapi
import os
import zipfile
import glob
import shutil as sh

cop_long_name=["Air temperature", "Capacity of soil to store water", "Daily maximum near-surface air temperature", "Daily minimum near-surface air temperature", "Eastward near-surface wind", "Eastward wind", "Evaporation including sublimation and transpiration", "Geopotential height", "Grid-cell area for atmospheric grid variables", "Grid-cell area for ocean variables", "Land ice area percentage", "Moisture in upper portion of soil column", "Near-surface air temperature", "Near-surface relative humidity", "Near-surface specific humidity", "Near-surface wind speed", "Northward near-surface wind", "Northward wind", "Percentage of the grid cell occupied by land including lakes", "Precipitation", "Relative humidity", "Sea area percentage", "Sea floor depth below geoid", "Sea ice thickness", "Sea level pressure", "Sea surface height above geoid", "Sea surface salinity", "Sea surface temperature", "Sea-ice area percentage on ocean grid", "Sea-ice mass per area", "Snow depth", "Snowfall flux", "Specific humidity", "Surface air pressure", "Surface altitude", "Surface downward eastward wind stress", "Surface downward northward wind stress", "Surface downwelling longwave radiation", "Surface downwelling shortwave radiation", "Surface snow amount", "Surface temperature", "Surface temperature of sea ice", "Surface upward latent heat flux", "Surface upward sensible heat flux", "Surface upwelling longwave radiation", "Surface upwelling shortwave radiation", "TOA incident shortwave radiation", "TOA outgoing longwave radiation", "TOA outgoing shortwave radiation", "Total cloud cover percentage", "Total runoff"]

os.chdir('/jarre/scenario/jlavoie/FreshEyes/copernicus/')
uniques=[]
cop_long_name={'monthly':["Air temperature", "Daily maximum near-surface air temperature", "Daily minimum near-surface air temperature", "Eastward near-surface wind", "Eastward wind", "Evaporation including sublimation and transpiration", "Geopotential height", "Moisture in upper portion of soil column", "Near-surface air temperature",  "Near-surface specific humidity", "Near-surface wind speed", "Northward near-surface wind", "Northward wind", "Precipitation", "Relative humidity", "Sea ice thickness", "Sea level pressure", "Sea surface height above geoid", "Sea surface salinity", "Sea surface temperature", "Sea-ice area percentage on ocean grid", "Sea-ice mass per area", "Snowfall flux", "Specific humidity", "Surface air pressure",  "Surface downward eastward wind stress", "Surface downward northward wind stress", "Surface downwelling longwave radiation", "Surface downwelling shortwave radiation", "Surface temperature", "Surface temperature of sea ice", "Surface upward latent heat flux", "Surface upward sensible heat flux", "Surface upwelling longwave radiation", "Surface upwelling shortwave radiation", "TOA incident shortwave radiation", "TOA outgoing longwave radiation", "TOA outgoing shortwave radiation", "Total cloud cover percentage", "Total runoff"],
 'daily':["Air temperature", "Daily maximum near-surface air temperature", "Daily minimum near-surface air temperature", "Eastward near-surface wind", "Eastward wind", "Evaporation including sublimation and transpiration", "Geopotential height",  "Moisture in upper portion of soil column", "Near-surface air temperature",  "Near-surface specific humidity", "Near-surface wind speed", "Northward near-surface wind", "Northward wind",  "Precipitation", "Relative humidity", "Sea ice thickness", "Sea level pressure", "Sea surface height above geoid", "Sea surface salinity", "Sea surface temperature", "Sea-ice area percentage on ocean grid", "Sea-ice mass per area", "Snow depth", "Snowfall flux", "Specific humidity", "Surface air pressure",  "Surface downward eastward wind stress", "Surface downward northward wind stress", "Surface downwelling longwave radiation", "Surface downwelling shortwave radiation", "Surface snow amount", "Surface temperature", "Surface temperature of sea ice", "Surface upward latent heat flux", "Surface upward sensible heat flux", "Surface upwelling longwave radiation", "Surface upwelling shortwave radiation", "TOA incident shortwave radiation", "TOA outgoing longwave radiation", "TOA outgoing shortwave radiation", "Total cloud cover percentage", "Total runoff"],
  'fixed': ["Capacity of soil to store water", "Grid-cell area for atmospheric grid variables", "Grid-cell area for ocean variables", "Land ice area percentage","Percentage of the grid cell occupied by land including lakes", "Sea area percentage", "Sea floor depth below geoid","Surface altitude",]
              }
for freq, names in cop_long_name.items():
    for var in names:
        for model in ["awi_cm_1_1_mr",'access_cm2']:
            var=var.lower().replace(' ','_').replace('-','_')
            try:

                dataset = "projections-cmip6"
                if freq=='fixed':
                    request = {
                        "temporal_resolution": freq,
                        "experiment": "historical",
                        "variable": var,
                        "model": model,
                        "area": [61, 0, 60, 1]
                    }
                else:
                    request = {
                        "temporal_resolution": freq,
                        "experiment": "historical",
                        "variable": var,
                       # "level": ["1"],
                        "model": model,
                        "year": ["1850"],
                        "month": ["01"],
                        "area": [61, 0, 60, 1]
                    }


                client = cdsapi.Client()
                name=client.retrieve(dataset, request).download()
                os.mkdir('unzip')
                with zipfile.ZipFile(name, 'r') as zip_ref:
                    zip_ref.extractall('unzip')

                unique='_'.join(glob.glob('unzip/*.nc')[0].split('/')[1].split('_')[:2])
                print(unique)
                uniques.append(unique)
                sh.rmtree('unzip')
                break
            except:
                print('no', var, freq,model)
print(uniques)
# Out:
# 2025-03-05 09:50:36,649 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-03-05 09:50:36,650 WARNING [2024-06-16T00:00:00] CDS API syntax is changed and some keys or parameter names may have also changed. To avoid requests failing, please use the "Show API request code" tool on the dataset Download Form to check you are using the correct syntax for your API request.
# 2025-03-05 09:50:38,063 INFO Request ID is dcfe6e60-e405-46cd-a5b9-f7f0eb3bd61d
# 2025-03-05 09:50:38,222 INFO status has been updated to accepted
# 2025-03-05 09:50:52,174 INFO status has been updated to running
# 2025-03-05 09:50:59,913 INFO status has been updated to successful
# ta_Amon
# 2025-03-05 09:51:04,018 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# ...

# %%
dataset = "projections-cmip6"
if freq=='fixed':
    request = {
        "temporal_resolution": freq,
        "experiment": "historical",
        "variable": var,
        "model": model,
        "area": [61, 0, 60, 1]
    }
else:
    request = {
        "temporal_resolution": freq,
        "experiment": "historical",
        "variable": var,
       # "level": ["1"],
        "model": model,
        "year": ["1850"],
        "month": ["01"],
        "area": [61, 0, 60, 1]
    }


client = cdsapi.Client()
name=client.retrieve(dataset, request).download()
os.mkdir('unzip')
with zipfile.ZipFile(name, 'r') as zip_ref:
    zip_ref.extractall('unzip')

unique='_'.join(glob.glob('unzip/*.nc')[0].split('/')[1].split('_')[:2])
print(unique)
uniques.append(unique)
sh.rmtree('unzip')
# Out:
# 'ta_Amon'

# %%
len(['ta_Amon', 'tasmax_Amon', 'tasmin_Amon', 'uas_Amon', 'ua_Amon', 'evspsbl_Amon', 'zg_Amon', 'tas_Amon', 'huss_Amon', 'sfcWind_Amon', 'vas_Amon', 'va_Amon', 'pr_Amon', 'hur_Amon', 'psl_Amon', 'prsn_Amon', 'hus_Amon', 'ps_Amon', 'tauu_Amon', 'tauv_Amon', 'rlds_Amon', 'rsds_Amon', 'ts_Amon', 'hfls_Amon', 'hfss_Amon', 'rlus_Amon', 'rsus_Amon', 'rsdt_Amon', 'rlut_Amon', 'rsut_Amon', 'clt_Amon',])
# Out:
# 31

# %%
out.download()
# Out:
# 'ae004f5327c56aa92c8e412d4a1a8b6a.zip'
