# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import re
import numpy as np
import json
import urllib.request 
import glob
import seaborn as sns

# to keep my paths secret
import xscen as xs
from xscen import CONFIG
xs.load_config('paths.yml', verbose=(__name__ == '__main__'), reset=True)

# %%
# get citation data and put it in a csv
# import requests
# import time
# import pandas as pd



# def get_datacite_citations(doi):
#     url = f"https://api.datacite.org/dois/{doi}"
#     try:
#         r = requests.get(url)
#         r.raise_for_status()
#         data = r.json()
#         return data["data"]["attributes"].get("citationCount", 0)
#     except Exception as e:
#         print(f"Error with {doi}: {e}")
#         return None

# path=f"{CONFIG['dir']}/citations/CMIP6_Data_References.csv"
# df=pd.read_csv(path, encoding="latin1")
# #df=df[df['EXPERIMENT_ID'].isnull()] # start with only source
# results = []
# for index, row in df.iterrows():
#     doi=row['DOI'].replace('https://doi.org/','')
#     results.append(get_datacite_citations(doi))
    
# df['num_citation']=results
# display(df)
# df.to_csv(path)

# %%
# open csv of data
df_ref= pd.read_csv(f"{CONFIG['dir']}/citations/CMIP6_Data_References.csv")
df_ref
# Out:
#       Unnamed: 0                                             DRS_ID  \
# 0              0                   CMIP6.AerChemMIP.AS-RCEC.TaiESM1
# 1              1       CMIP6.AerChemMIP.AS-RCEC.TaiESM1.hist-piNTCF
# 2              2           CMIP6.AerChemMIP.AS-RCEC.TaiESM1.histSST
# 3              3    CMIP6.AerChemMIP.AS-RCEC.TaiESM1.histSST-piNTCF
# 4              4       CMIP6.AerChemMIP.AS-RCEC.TaiESM1.piClim-NTCF
# ...          ...                                                ...
# 3004        3004  input4MIPs.CMIP6.ScenarioMIP.UofMD.UofMD-landS...
# 3005        3005  input4MIPs.CMIP6.ScenarioMIP.UofMD.UofMD-landS...
# 3006        3006  input4MIPs.CMIP6.ScenarioMIP.UofMD.UofMD-landS...
# 3007        3007  input4MIPs.CMIP6.ScenarioMIP.UofMD.UofMD-landS...
# 3008        3008  input4MIPs.CMIP6.ScenarioMIP.UofMD.UofMD-landS...
#
#          MIP_ERA ACTIVITY_ID INSTITUTION_ID SOURCE_ID  \
# 0          CMIP6  AerChemMIP        AS-RCEC   TaiESM1
# 1          CMIP6  AerChemMIP        AS-RCEC   TaiESM1
# 2          CMIP6  AerChemMIP        AS-RCEC   TaiESM1
# 3          CMIP6  AerChemMIP        AS-RCEC   TaiESM1
# 4          CMIP6  AerChemMIP        AS-RCEC   TaiESM1
# ...          ...         ...            ...       ...
# 3004  input4MIPs       CMIP6    ScenarioMIP     UofMD
# 3005  input4MIPs       CMIP6    ScenarioMIP     UofMD
# 3006  input4MIPs       CMIP6    ScenarioMIP     UofMD
# 3007  input4MIPs       CMIP6    ScenarioMIP     UofMD
# 3008  input4MIPs       CMIP6    ScenarioMIP     UofMD
#
#                              EXPERIMENT_ID  \
# 0                                      NaN
# 1                              hist-piNTCF
# 2                                  histSST
# 3                           histSST-piNTCF
# 4                              piClim-NTCF
# ...                                    ...
# 3004   UofMD-landState-MAGPIE-ssp534-2-1-e
# 3005   UofMD-landState-MAGPIE-ssp534-2-1-f
# 3006   UofMD-landState-MAGPIE-ssp585-2-1-e
# 3007   UofMD-landState-MAGPIE-ssp585-2-1-f
# 3008  UofMD-landState-MESSAGE-ssp245-2-1-f
#
#                                                  DOI  \
# 0           https://doi.org/10.22033/ESGF/CMIP6.9682
# 1           https://doi.org/10.22033/ESGF/CMIP6.9744
# 2           https://doi.org/10.22033/ESGF/CMIP6.9747
# 3           https://doi.org/10.22033/ESGF/CMIP6.9752
# 4           https://doi.org/10.22033/ESGF/CMIP6.9790
# ...                                              ...
# 3004  https://doi.org/10.22033/ESGF/input4MIPs.10922
# 3005   https://doi.org/10.22033/ESGF/input4MIPs.9949
# 3006  https://doi.org/10.22033/ESGF/input4MIPs.10923
# 3007   https://doi.org/10.22033/ESGF/input4MIPs.1662
# 3008   https://doi.org/10.22033/ESGF/input4MIPs.1886
#
#                                          Data Reference       License  \
# 0     Tsai, I-Chun; Lee, Wei-Liang; Hsu, Huang-Hsiun...     CC BY 4.0
# 1     Tsai, I-Chun; Lee, Wei-Liang; Hsu, Huang-Hsiun...     CC BY 4.0
# 2     Tsai, I-Chun; Lee, Wei-Liang; Hsu, Huang-Hsiun...     CC BY 4.0
# 3     Tsai, I-Chun; Lee, Wei-Liang; Hsu, Huang-Hsiun...     CC BY 4.0
# 4     Tsai, I-Chun; Lee, Wei-Liang; Hsu, Huang-Hsiun...     CC BY 4.0
# ...                                                 ...           ...
# 3004  Hurtt, George; Chini, Louise; Sahajpal, Ritvik...  CC BY-SA 4.0
# 3005  Hurtt, George; Chini, Louise; Sahajpal, Ritvik...  CC BY-SA 4.0
# 3006  Hurtt, George; Chini, Louise; Sahajpal, Ritvik...  CC BY-SA 4.0
# 3007  Hurtt, George; Chini, Louise; Sahajpal, Ritvik...  CC BY-SA 4.0
# 3008  Hurtt, George; Chini, Louise; Sahajpal, Ritvik...  CC BY-SA 4.0
#
#                                          License Uri  num_citation
# 0       https://creativecommons.org/licenses/by/4.0/           3.0
# 1       https://creativecommons.org/licenses/by/4.0/           0.0
# 2       https://creativecommons.org/licenses/by/4.0/           0.0
# 3       https://creativecommons.org/licenses/by/4.0/           0.0
# 4       https://creativecommons.org/licenses/by/4.0/           0.0
# ...                                              ...           ...
# 3004  http://creativecommons.org/licenses/by-sa/4.0/           0.0
# 3005  http://creativecommons.org/licenses/by-sa/4.0/           0.0
# 3006  http://creativecommons.org/licenses/by-sa/4.0/           0.0
# 3007  http://creativecommons.org/licenses/by-sa/4.0/           2.0
# 3008  http://creativecommons.org/licenses/by-sa/4.0/           0.0
#
# [3009 rows x 12 columns]

# %%
df_ref.num_citation.sum()
# Out:
# 27456.0

# %%
df1=df_ref[df_ref["SOURCE_ID"]=='EC-Earth3']
df1[df1["EXPERIMENT_ID"].isnull()]
# Out:
#       Unnamed: 0                                           DRS_ID MIP_ERA  \
# 833          833         CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3   CMIP6
# 1190        1190        CMIP6.DAMIP.EC-Earth-Consortium.EC-Earth3   CMIP6
# 1333        1333         CMIP6.DCPP.EC-Earth-Consortium.EC-Earth3   CMIP6
# 1787        1787       CMIP6.LS3MIP.EC-Earth-Consortium.EC-Earth3   CMIP6
# 1983        1983         CMIP6.OMIP.EC-Earth-Consortium.EC-Earth3   CMIP6
# 2062        2062        CMIP6.PAMIP.EC-Earth-Consortium.EC-Earth3   CMIP6
# 2181        2181         CMIP6.PMIP.EC-Earth-Consortium.EC-Earth3   CMIP6
# 2295        2295        CMIP6.RFMIP.EC-Earth-Consortium.EC-Earth3   CMIP6
# 2575        2575  CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3   CMIP6
#
#       ACTIVITY_ID       INSTITUTION_ID  SOURCE_ID EXPERIMENT_ID  \
# 833          CMIP  EC-Earth-Consortium  EC-Earth3           NaN
# 1190        DAMIP  EC-Earth-Consortium  EC-Earth3           NaN
# 1333         DCPP  EC-Earth-Consortium  EC-Earth3           NaN
# 1787       LS3MIP  EC-Earth-Consortium  EC-Earth3           NaN
# 1983         OMIP  EC-Earth-Consortium  EC-Earth3           NaN
# 2062        PAMIP  EC-Earth-Consortium  EC-Earth3           NaN
# 2181         PMIP  EC-Earth-Consortium  EC-Earth3           NaN
# 2295        RFMIP  EC-Earth-Consortium  EC-Earth3           NaN
# 2575  ScenarioMIP  EC-Earth-Consortium  EC-Earth3           NaN
#
#                                             DOI  \
# 833     https://doi.org/10.22033/ESGF/CMIP6.181
# 1190  https://doi.org/10.22033/ESGF/CMIP6.14701
# 1333    https://doi.org/10.22033/ESGF/CMIP6.227
# 1787    https://doi.org/10.22033/ESGF/CMIP6.218
# 1983  https://doi.org/10.22033/ESGF/CMIP6.14702
# 2062   https://doi.org/10.22033/ESGF/CMIP6.9881
# 2181  https://doi.org/10.22033/ESGF/CMIP6.11221
# 2295    https://doi.org/10.22033/ESGF/CMIP6.242
# 2575    https://doi.org/10.22033/ESGF/CMIP6.251
#
#                                          Data Reference    License  \
# 833   EC-Earth Consortium (EC-Earth) (2019). EC-Eart...  CC BY 4.0
# 1190  EC-Earth Consortium (EC-Earth) (2020). EC-Eart...  CC BY 4.0
# 1333  EC-Earth Consortium (EC-Earth) (2019). EC-Eart...  CC BY 4.0
# 1787  EC-Earth Consortium (EC-Earth) (2020). EC-Eart...  CC BY 4.0
# 1983  EC-Earth Consortium (EC-Earth) (2020). EC-Eart...  CC BY 4.0
# 2062  EC-Earth Consortium (EC-Earth) (2021). EC-Eart...  CC BY 4.0
# 2181  EC-Earth Stockholm group (EC-Earth-S) (2023). ...  CC BY 4.0
# 2295  EC-Earth Consortium (EC-Earth) (2020). EC-Eart...  CC BY 4.0
# 2575  EC-Earth Consortium (EC-Earth) (2019). EC-Eart...  CC BY 4.0
#
#                                        License Uri  num_citation
# 833   https://creativecommons.org/licenses/by/4.0/          20.0
# 1190  https://creativecommons.org/licenses/by/4.0/           2.0
# 1333  https://creativecommons.org/licenses/by/4.0/           0.0
# 1787  https://creativecommons.org/licenses/by/4.0/           0.0
# 1983  https://creativecommons.org/licenses/by/4.0/           0.0
# 2062  https://creativecommons.org/licenses/by/4.0/           0.0
# 2181  https://creativecommons.org/licenses/by/4.0/           0.0
# 2295  https://creativecommons.org/licenses/by/4.0/           0.0
# 2575  https://creativecommons.org/licenses/by/4.0/          13.0

# %%
#downloaded
df_source= pd.read_csv(f"{CONFIG['dir']}/cmcc/cmip6-sources_13_01_2025.csv")
display(df_source)
# published
df_model= pd.read_csv(f"{CONFIG['dir']}/cmcc/cmip6-models_13_01_2025.csv")
display(df_model)
# Out:
#     source_id_name  number_of_downloads  total_size_GB
# 0        EC-EARTH3             70435077     5091534.63
# 1     IPSL-CM6A-LR              2965261     3845623.97
# 2    MPI-ESM1-2-HR              6702396     3490023.05
# 3            CESM2              2925271     2611059.73
# 4    EC-EARTH3-VEG             26135094     2261190.15
# ..             ...                  ...            ...
# 140      PICLIM-BC                    4           0.00
# 141         2BANDS                    6           0.00
# 142     PICLIM-SO2                    3           0.00
# 143      PICLIM-OC                    3           0.00
# 144     PICLIM-GHG                    2           0.00
#
# [145 rows x 3 columns]
#            dimension  number_of_datasets  total_size_TB
# 0          4AOP-v1-5                  12           0.00
# 1         ACCESS-CM2               49179         165.98
# 2      ACCESS-ESM1-5              323856         670.33
# 3         ACCESS-OM2                 608           5.77
# 4     ACCESS-OM2-025                 214          24.18
# ..               ...                 ...            ...
# 122   TaiESM1-TIMCOM                 198           2.71
# 123  TaiESM1-TIMCOM2                 169           2.28
# 124      UKESM1-0-LL              218607         743.47
# 125      UKESM1-1-LL                2445           6.44
# 126    UKESM1-ice-LL                 704           1.01
#
# [127 rows x 3 columns]

# %% [markdown]
# # source

# %%
# sum all the only source data
df_refsource=df_ref[df_ref['EXPERIMENT_ID'].isnull()].groupby('SOURCE_ID')['num_citation'].sum().reset_index()
df_refsource['SOURCE_ID_CAP']=pd.DataFrame(df_refsource['SOURCE_ID'].str.upper())
#align names
df_source=df_source.rename(columns={'source_id_name': 'SOURCE_ID_CAP', 'total_size_GB': 'total_size_GB_downloaded'})
df_model=df_model.rename(columns={'dimension': 'SOURCE_ID', 'total_size_TB':'total_size_TB uploaded'})
#merge
df_refsource= pd.merge(df_refsource,df_source, on='SOURCE_ID_CAP', )
df_refsource= pd.merge(df_model,df_refsource, on='SOURCE_ID')
df_refsource
# Out:
#            SOURCE_ID  number_of_datasets  total_size_TB uploaded  \
# 0          4AOP-v1-5                  12                    0.00
# 1         ACCESS-CM2               49179                  165.98
# 2      ACCESS-ESM1-5              323856                  670.33
# 3         ACCESS-OM2                 608                    5.77
# 4     ACCESS-OM2-025                 214                   24.18
# ..               ...                 ...                     ...
# 121   TaiESM1-TIMCOM                 198                    2.71
# 122  TaiESM1-TIMCOM2                 169                    2.28
# 123      UKESM1-0-LL              218607                  743.47
# 124      UKESM1-1-LL                2445                    6.44
# 125    UKESM1-ice-LL                 704                    1.01
#
#      num_citation    SOURCE_ID_CAP  number_of_downloads  \
# 0             0.0        4AOP-V1-5                  304
# 1            38.0       ACCESS-CM2              1078208
# 2            61.0    ACCESS-ESM1-5              2865244
# 3             4.0       ACCESS-OM2                14494
# 4             3.0   ACCESS-OM2-025                30275
# ..            ...              ...                  ...
# 121           0.0   TAIESM1-TIMCOM                  473
# 122           0.0  TAIESM1-TIMCOM2                  531
# 123          70.0      UKESM1-0-LL              1243827
# 124           2.0      UKESM1-1-LL                 4171
# 125           0.0    UKESM1-ICE-LL                  134
#
#      total_size_GB_downloaded
# 0                        0.11
# 1                   594693.43
# 2                  1259006.45
# 3                     3446.97
# 4                    20201.69
# ..                        ...
# 121                   1080.37
# 122                   1428.01
# 123                 965355.79
# 124                   2470.39
# 125                     40.61
#
# [126 rows x 7 columns]

# %% [markdown]
# # experiment

# %%
df_exp= pd.read_csv(f"{CONFIG['dir']}/cmcc/cmip6-experiments_13_01_2025.csv")
# sum all the only source data
df_refexp=df_ref[~df_ref['EXPERIMENT_ID'].isnull()].groupby('EXPERIMENT_ID')['num_citation'].sum().reset_index()
df_refexp
#align names
df_exp=df_exp.rename(columns={'experiment_name': 'EXPERIMENT_ID', 'total_size_GB': 'total_size_GB_downloaded'})
#merge
df_refexp= pd.merge(df_refexp,df_exp, on='EXPERIMENT_ID', )
df_refexp
# Out:
#           EXPERIMENT_ID  num_citation  number_of_downloads  \
# 0         abrupt-solm4p           0.0                 4230
# 1         abrupt-solp4p           0.0                 5682
# 2                  amip         464.0              1527968
# 3             amip-hist          65.0                43135
# 4              amip-hld           0.0                  412
# ..                  ...           ...                  ...
# 70       ssp585-withism           0.0                 3834
# 71         volc-long-eq           1.0                 4538
# 72   volc-pinatubo-full           0.0                 7531
# 73  volc-pinatubo-strat           0.0                 1107
# 74   volc-pinatubo-surf           0.0                 1150
#
#     total_size_GB_downloaded
# 0                    3705.70
# 1                    4415.05
# 2                  984812.30
# 3                   21511.14
# 4                     149.36
# ..                       ...
# 70                    836.36
# 71                    433.36
# 72                    151.26
# 73                     21.04
# 74                     20.57
#
# [75 rows x 4 columns]

# %%
fig, axs= plt.subplots(1,2,figsize=(15,5))


g=sns.scatterplot(
    data=df_refsource[df_refsource['num_citation']>5],
    x="total_size_GB_downloaded", y="num_citation",
    ax=axs[0]
)
g.set(xscale="log",xlabel="Total size of downloads on ESGF (GB)",ylabel="Number of citation", title='a) Source')

g = sns.scatterplot(
    data=df_refexp[df_refexp['num_citation']>10],
    x="total_size_GB_downloaded", y="num_citation",ax=axs[1]
)
g.set(xscale="log",yscale='log',xlabel="Total size of downloads on ESGF (GB)",ylabel="Number of citation", title='b) Experiment')

# axs[0].set_xscale('log')
# axs[0].set_xlabel("Total download size (GB)")
# axs[0].set_ylabel("Number of citation")
#g.set(xscale="log",xlabel="Total download size (GB)",ylabel="Number of citation")
#plt.title('source')
# Out:
# [None,
#  None,
#  Text(0.5, 0, 'Total size of downloads on ESGF (GB)'),
#  Text(0, 0.5, 'Number of citation'),
#  Text(0.5, 1.0, 'b) Experiment')]

# %%
df_refsource[df_refsource["SOURCE_ID"]=='EC-Earth3']
# Out:
#     SOURCE_ID  number_of_datasets  total_size_TB uploaded  num_citation  \
# 40  EC-Earth3              551873                 2294.36          35.0
#
#    SOURCE_ID_CAP  number_of_downloads  total_size_GB_downloaded
# 40     EC-EARTH3             70435077                5091534.63
